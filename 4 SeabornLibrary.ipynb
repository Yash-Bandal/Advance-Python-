# %% [markdown]
# #Seaborn Library in Python
#
# -Seaborn is an amazing visualization library for statistical graphics plotting in Python. It provides beautiful default styles and color palettes to make statistical plots more attractive. It is built on top matplotlib library and is also closely integrated with the data structures from pandas.

# %% [markdown]
# #importing required Libraries

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# #sample data

# %% [markdown]
# #tips
# Loads the tips dataset, which contains information about tips received by waitstaff in a restaurant, including the total bill, tip amount, sex of the bill payer, whether they are a smoker, day of the week, time of day, and the size of the party.
# #iris
# -Loads the iris dataset, one of the most famous datasets in statistics and machine learning. It contains measurements of sepal length, sepal width, petal length, and petal width for three species of iris flowers
# #flights
# -Loads the flights dataset, which contains the number of passengers on flights per month from 1949 to 1960. This dataset is typically used for time series analysis, heatmaps, and line plots.
# #fmri
# -Loads the fmri dataset, which contains functional magnetic resonance imaging (fMRI) data from a study on the brain's response to visual stimuli.

# %%
tips = sns.load_dataset("tips")
iris = sns.load_dataset("iris")
flights = sns.load_dataset("flights")
fmri = sns.load_dataset("fmri")

# %% [markdown]
# #Some basic Functions

# %% [markdown]
# #(1)title() =>

# %%
#hue="species": Adds a third dimension to the plot by color-coding the data points based on the species column in the iris dataset.
#Each species of iris flower (e.g., setosa, versicolor, virginica) will be represented by a different color, making it easy to differentiate between them in the plot.
sns.scatterplot(data=iris, x='sepal_length', y='sepal_width', hue='species')
plt.title('Sepal Length vs Sepal Width')
# Out:
# Text(0.5, 1.0, 'Sepal Length vs Sepal Width')

# %% [markdown]
# #(2)legend() =>

# %%
sns.scatterplot(data=iris, x='sepal_length', y='sepal_width', hue='species')
plt.title('Sepal Length vs Sepal Width')
plt.legend(title='Species')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-83d2ddef0c05> in <cell line: 1>()
# ----> 1 sns.scatterplot(data=iris, x='sepal_length', y='sepal_width', hue='species')
#       2 plt.title('Sepal Length vs Sepal Width')
#       3 plt.legend(title='Species')
#
# NameError: name 'sns' is not defined

# %% [markdown]
# #plotting functions

# %% [markdown]
# # (1)sns.lineplot() =>
# used to create a line plot, which is useful for visualizing trends in data over a continuous variable, like time

# %%
#x="timepoint": Specifies that the data for the x-axis of the plot should come from the timepoint column in the fmri dataset
#y="signal": Specifies that the data for the y-axis of the plot should come from the signal column in the fmri dataset.
#data=fmri: Specifies that the data for the plot should come from the fmri dataset, which was loaded earlier using sns.load_dataset("fmri")
sns.lineplot(x = "timepoint" , y = "signal" , data = fmri)
plt.show()

# %% [markdown]
# #(2)sns.scatterplot() =>
# -This function from Seaborn is used to create a scatter plot, which is a type of plot that shows the relationship between two continuous variables.

# %%
#x="sepal_length": Specifies that the data for the x-axis of the plot should come from the sepal_length column in the iris
#y="sepal_width": Specifies that the data for the y-axis of the plot should come from the sepal_width column in the iris dataset.
sns.scatterplot(x = "sepal_length" , y = "sepal_width" , data = iris)
plt.show()

# %% [markdown]
# #(3)sns.relplot() =>
# -This function creates a relational plot, which is a flexible function in Seaborn that can be used to create scatter plots or line plots.

# %%
#hue="species": Adds a third dimension to the plot by color-coding the data points based on the species column in the iris dataset.
#Each species of iris flower (e.g., setosa, versicolor, virginica) will be represented by a different color, making it easy to differentiate between them in the plot.
sns.relplot(x = "sepal_length" , y = "sepal_width" , hue = "species" , data = iris)
plt.show()

# %% [markdown]
# #(4)sns.catplot() =>
# -sns.catplot: This function creates a categorical plot, which is used to visualize data where one or more variables are categorical.

# %%
#hue="smoker": Adds a third dimension to the plot by color-coding the data points based on the smoker column in the tips dataset.
#This column indicates whether the bill payer is a smoker (Yes) or not (No), with different colors representing each group.
sns.catplot(x = "day" , y = "total_bill" , hue = "smoker" , data = tips)
plt.show()

# %% [markdown]
# #(5)sns.stripplot() =>
# -This function creates a strip plot, which is a type of categorical plot that displays individual data points along a categorical axis.

# %%
sns.stripplot(x = "day" , y = "total_bill" , data = tips)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-271c91b04a2b> in <cell line: 1>()
# ----> 1 sns.stripplot(x = "day" , y = "total_bill" , data = tips)
#       2 plt.show()
#
# NameError: name 'sns' is not defined

# %% [markdown]
# #(6)sns.swarmplot() =>
# -This function creates a swarm plot, which is similar to a strip plot but with additional adjustments to avoid overlapping points

# %%
 #It shows the distribution of a continuous variable (like total_bill) along a categorical axis (like day) while arranging points to avoid overlap.
 #It’s useful for visualizing the distribution of data points in a categorical context, providing a clearer view of the data density and distribution.
sns.swarmplot(x = "day" , y = "total_bill" , data = tips)
plt.show()

# %% [markdown]
# #(7)sns.boxplot() =>
# - This function creates a box plot, which is used to visualize the distribution of a continuous variable (like total_bill) across different categories (like day)

# %%
sns.boxplot(x = "day" , y = "total_bill" , data = tips)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e2f5df08b93e> in <cell line: 1>()
# ----> 1 sns.boxplot(x = "day" , y = "total_bill" , data = tips)
#       2 plt.show()
#
# NameError: name 'sns' is not defined

# %% [markdown]
# #(8)sns.violinplot() =>
# This function creates a violin plot, which combines aspects of a box plot and a density plot. It shows the distribution of a continuous variable (like total_bill) across different categories (like day). The shape of each "violin" represents the density of the data, providing a visualization of the distribution and its variations.

# %%
sns.violinplot(x = "day" , y = "total_bill" , data = tips)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-026443afa1da> in <cell line: 1>()
# ----> 1 sns.violinplot(x = "day" , y = "total_bill" , data = tips)
#       2 plt.show()
#
# NameError: name 'sns' is not defined

# %% [markdown]
# #(9)sns.barplot() =>
# - This function creates a bar plot, which is used to visualize the average values of a continuous variable

# %%
#used to visualize the average values of a continuous variable (like total_bill) for different categories (like day). Bar plots are useful for comparing the central tendency of data across categories
sns.barplot(x = "day" , y = "total_bill" , data = tips)
plt.show()

# %% [markdown]
# #(10)sns.pointplot() =>
# -This function creates a point plot, which is useful for showing the relationship between a categorical variable and a continuous variable. It displays the average values of the continuous variable for each category and can also show confidence intervals around the mean.

# %%
sns.pointplot(x = "day" , y = "total_bill" , data = tips)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-eeeb93cc5a8c> in <cell line: 1>()
# ----> 1 sns.pointplot(x = "day" , y = "total_bill" , data = tips)
#       2 plt.show()
#
# NameError: name 'sns' is not defined

# %% [markdown]
# #(11)sns.countplot() =>
# -This function creates a count plot, which is used to show the number of occurrences of each category in a categorical variable.
# - It displays a bar for each category with the height of the bar representing the count of occurrences in the dataset.

# %%
sns.countplot(x = "day" , data = tips)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-7ce621fe1da0> in <cell line: 1>()
# ----> 1 sns.countplot(x = "day" , data = tips)
#       2 plt.show()
#
# NameError: name 'sns' is not defined

# %% [markdown]
# #(12)sns.histplot()  =>
# - This function creates a histogram, which is used to visualize the distribution of a continuous variable. It shows how frequently data points fall into different ranges or bins.

# %%
sns.histplot(tips["total_bill"] , bins = 10)
plt.show()

# %% [markdown]
# #(13)sns.kdeplot() =>
# - This function creates a KDE plot, which is used to estimate and visualize the probability density function of a continuous variable.
# -The KDE plot provides a smooth, continuous estimate of the distribution of the data, which is helpful for understanding the underlying distribution and density of the variable

# %%
sns.kdeplot(tips["total_bill"])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-b89ff7781008> in <cell line: 1>()
# ----> 1 sns.kdeplot(tips["total_bill"])
#       2 plt.show()
#
# NameError: name 'sns' is not defined

# %% [markdown]
# #(14)sns.lmplot() =>
# - used to plot data and model relationships using linear regression.
# -It creates a scatter plot of two variables and fits a linear regression model to the data, displaying the regression line

# %%
sns.lmplot(x="total_bill", y="tip", data=tips)
plt.title("Linear Regression on Tips Dataset")
plt.show()

# %% [markdown]
# #(15)sns.regplot () =>
# -used to create a scatter plot with an optional linear regression line. It plots the data points and fits a regression model to the data

# %%
sns.regplot(x="total_bill", y="tip", data=tips)
plt.title("Regression Plot on Tips Dataset")
plt.show()

# %% [markdown]
# #(16)sns.residplot () =>
# -This function in Seaborn creates a residual plot.
#
# -A residual plot shows the residuals (the differences between observed and predicted values) on the y-axis and the independent variable on the x-axis. It's used to assess the goodness of fit of a regression model.

# %%
sns.residplot(x="total_bill", y="tip", data=tips)
plt.title("Residual Plot on Tips Dataset")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-7f119f66a9e7> in <cell line: 1>()
# ----> 1 sns.residplot(x="total_bill", y="tip", data=tips)
#       2 plt.title("Residual Plot on Tips Dataset")
#       3 plt.show()
#
# NameError: name 'sns' is not defined

# %% [markdown]
# #(17)flights_pivot () =>
# - The pivot method reshapes the data into a pivot table

# %%
#"month": Sets the month as the index (rows) of the pivot table.
#"year": Sets the year as the columns of the pivot table.
#"passengers": The values in the table are the number of passengers.
# For 'flights' dataset
flights_pivot = flights.pivot("month", "year", "passengers")
sns.heatmap(flights_pivot, annot=True, fmt="d")
plt.title("Heatmap of Flights Dataset")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a53bc2037c80> in <cell line: 5>()
#       3 #"passengers": The values in the table are the number of passengers.
#       4 # For 'flights' dataset
# ----> 5 flights_pivot = flights.pivot("month", "year", "passengers")
#       6 sns.heatmap(flights_pivot, annot=True, fmt="d")
#       7 plt.title("Heatmap of Flights Dataset")
#
# NameError: name 'flights' is not defined

# %% [markdown]
# #(18)sns.clustermap () =>
# -This function in Seaborn creates a clustered heatmap, which is a heatmap where the rows and columns are rearranged based on hierarchical clustering.
#
# -Clustering groups similar rows and columns together, allowing for the visualization of patterns in the data.

# %%
sns.clustermap(flights_pivot, annot=True, fmt="d")
plt.title("Clustered Heatmap of Flights Dataset")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-f7bdc1a09e20> in <cell line: 1>()
# ----> 1 sns.clustermap(flights_pivot, annot=True, fmt="d")
#       2 plt.title("Clustered Heatmap of Flights Dataset")
#       3 plt.show()
#
# NameError: name 'flights_pivot' is not defined

# %% [markdown]
# #(19)sns.pairplot () =>
# -creates a pairplot, which is a matrix of scatterplots that shows relationships between pairs of variables in the dataset.
#
# -Each variable in the dataset is plotted against each other variable.

# %%
#hue="species": This argument tells Seaborn to color the data points by the species column, allowing you to distinguish between the three species of Iris flowers.
sns.pairplot(iris, hue="species")
plt.title("Pairplot of Iris Dataset")
plt.show()

# %% [markdown]
# #(20)sns.jointplot () =>
# -Setting kind="hex" creates a hexbin plot, where data points are binned into hexagons, and the color intensity within each hexagon represents the number of observations.
#
# -This is useful for visualizing the density of data points when there are many overlapping points.

# %%
sns.jointplot(x="total_bill", y="tip", data=tips, kind="hex")
plt.title("Jointplot on Tips Dataset")
plt.show()

# %% [markdown]
# #(21)sns.rugplot () =>
# -This function from the Seaborn library creates a rug plot. A rug plot is a simple visualization that places a small tick mark along the x-axis (or y-axis) for each data point in a dataset.

# %%
sns.rugplot(tips['total_bill'])
plt.title("Rugplot on Tips Dataset")
plt.show()

# %% [markdown]
# #(22)sns.PairGrid () =>
# -The PairGrid is a powerful Seaborn tool that allows you to create a grid of subplots for visualizing pairwise relationships in a dataset

# %%
g = sns.PairGrid(iris)
g.map_upper(sns.scatterplot)
g.map_lower(sns.kdeplot)
g.map_diag(sns.histplot)
plt.title("PairGrid on Iris Dataset")
plt.show()

# %% [markdown]
# #(23)sns.despine () =>
# - This function removes the top and right spines (borders) from the plot. Removing these spines often makes plots look cleaner and less cluttered, focusing the viewer's attention on the data itself.

# %%
# Create a basic plot
sns.boxplot(x="species", y="sepal_length", data=iris)
sns.despine()  # Remove the top and right spines
plt.title("Boxplot with Despine on Iris Dataset")
plt.show()

# %% [markdown]
# #(24)sns.set_palette () =>
# -This function generates a pair plot, which is a grid of scatter plots and histograms (or KDE plots) that show pairwise relationships between variables in a dataset.

# %%
# This line sets the color palette for all Seaborn plots that follow. The palette used here is "husl", which stands for Hue, Saturation, and Lightness (HUSL)
sns.set_palette("husl")

# Create a plot with the set palette
sns.pairplot(iris, hue="species")
plt.title("Pairplot with Husl Palette on Iris Dataset")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-2593d1f8d3ef> in <cell line: 2>()
#       1 # This line sets the color palette for all Seaborn plots that follow. The palette used here is "husl", which stands for Hue, Saturation, and Lightness (HUSL)
# ----> 2 sns.set_palette("husl")
#       3
#       4 # Create a plot with the set palette
#       5 sns.pairplot(iris, hue="species")
#
# NameError: name 'sns' is not defined

# %% [markdown]
# #(25)sns.color_palette () =>
# -This function generates a color palette with a specified number of colors.

# %%
#"viridis": The viridis palette is a perceptually uniform color map that transitions from dark purple to bright yellow-green
#5: This specifies the number of colors to retrieve from the viridis palette. In this case, five distinct colors are selected from the palette and stored in the variable palette
#sns.palplot(palette): This function displays a horizontal bar plot of the colors in the palette.
palette = sns.color_palette("viridis", 5)
sns.palplot(palette)
plt.title("Viridis Color Palette")
plt.show()

# %% [markdown]
# #(26)sns.husl_palette() =>
# -This function generates a color palette with a specified number of colors using the HUSL color space

# %%
husl_palette = sns.husl_palette(5)
sns.palplot(husl_palette)
plt.title("HUSL Palette")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-d657acd3464a> in <cell line: 1>()
# ----> 1 husl_palette = sns.husl_palette(5)
#       2 sns.palplot(husl_palette)
#       3 plt.title("HUSL Palette")
#       4 plt.show()
#
# NameError: name 'sns' is not defined

# %% [markdown]
# #(27)This function generates a sequential color palette that transitions from light to dark based on a specified base color.

# %%
# Create a light color palette
light_palette = sns.light_palette("purple", n_colors=5)
sns.palplot(light_palette)
plt.title("Light Purple Palette")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-2eaffc2a50a2> in <cell line: 2>()
#       1 # Create a light color palette
# ----> 2 light_palette = sns.light_palette("purple", n_colors=5)
#       3 sns.palplot(light_palette)
#       4 plt.title("Light Purple Palette")
#       5 plt.show()
#
# NameError: name 'sns' is not defined

# %% [markdown]
# #(28)sns.dark_palette () =>
# -This function generates a sequential color palette that transitions from a dark shade to a slightly lighter shade of the specified base color.

# %%
# Create a dark color palette
dark_palette = sns.dark_palette("blue", n_colors=5)
sns.palplot(dark_palette)
plt.title("Dark Blue Palette")
plt.show()

# %% [markdown]
# #(29)sns.diverging_palette () =>
# -This function generates a diverging color palette, which is useful for visualizing data where you want to highlight differences from a central point, with two contrasting colors on either end of the palett

# %%
#220: This represents the hue (color) for one end of the palette. In this case, 220 corresponds to a shade of blue.
#20: This represents the hue for the other end of the palette, which corresponds to a shade of red.
# n=7: Specifies the number of colors to include in the palette
diverging_palette = sns.diverging_palette(220,20, n=7)
sns.palplot(diverging_palette)
plt.title("Diverging Palette from Red to Blue")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-20a5aeaa502a> in <cell line: 4>()
#       2 #20: This represents the hue for the other end of the palette, which corresponds to a shade of red.
#       3 # n=7: Specifies the number of colors to include in the palette
# ----> 4 diverging_palette = sns.diverging_palette(220,20, n=7)
#       5 sns.palplot(diverging_palette)
#       6 plt.title("Diverging Palette from Red to Blue")
#
# NameError: name 'sns' is not defined

# %% [markdown]
# #(30)sns.mpl_palette () =>
# - This function retrieves a color palette from Matplotlib's predefined color sets.

# %%
#Set1 - offering bright, distinct colors that are easy to distinguish.
#5: Specifies the number of colors to include from the "Set1" palette. In this case, the first 5 colors from the "Set1" palette will be selected.
mpl_palette = sns.mpl_palette("Set1", 5)
sns.palplot(mpl_palette)
plt.title("Matplotlib 'Set1' Palette")
plt.show()

# %% [markdown]
# #(31)sns.blend_palette () =>
# -This function creates a color palette that transitions smoothly between two specified colors

# %%
blend_palette = sns.blend_palette(["red", "blue"], n_colors=5)
sns.palplot(blend_palette)
plt.title("Blended Palette from Red to Blue")
plt.show()

# %% [markdown]
# #(32)sns.xkcd_palette () =>
# - This function creates a color palette using color names from the XKCD color survey. XKCD is a webcomic that includes a color survey with a range of descriptive color names.

# %%
# Create a palette using XKCD color names
xkcd_palette = sns.xkcd_palette(["pale red", "medium green", "denim blue"])
sns.palplot(xkcd_palette)
plt.title("XKCD Color Palette")
plt.show()

# %% [markdown]
# #(33)sns.crayon_palette () =>
# -This function creates a color palette using specific Crayola crayon color

# %%
crayon_palette = sns.crayon_palette(["Cerulean", "Fuzzy Wuzzy", "Gold"])
sns.palplot(crayon_palette)
plt.title("Crayola Crayon Palette")
plt.show()

# %% [markdown]
# #(34)sns.color_codes () =>
# -This function sets the color code style for subsequent plots in Seaborn

# %%
sns.set_color_codes("dark")
sns.barplot(x="day", y="total_bill", data=tips, color="b")  # 'b' is blue
plt.title("Barplot Using Color Codes")
plt.show()

# %% [markdown]
# #(35)sns.set () =>
# -This function sets the aesthetic parameters for Seaborn plots.

# %%
#style="darkgrid": Applies the "darkgrid" style, which adds a dark grid background to the plots.
#palette="muted": Sets the color palette to "muted," which provides a set of subdued colors. This palette is useful for a more understated color scheme in plots

sns.set(style="darkgrid", palette="muted")

# Plot with custom settings
sns.scatterplot(x="total_bill", y="tip", data=tips)
plt.title("Scatterplot with Custom Settings")
plt.show()

# Reset to default Seaborn settings
sns.reset_defaults()

# Plot with default settings
sns.scatterplot(x="total_bill", y="tip", data=tips)
plt.title("Scatterplot with Default Settings")
plt.show()

# %% [markdown]
# #(36)sns.reset_orig() =>
#  - Reset the Matplotlib Configuration to Original Values
# - Sets the aesthetic parameters for Seaborn plots.

# %%
# Apply custom settings
sns.set(style="whitegrid", palette="dark")

# Plot with custom settings
sns.boxplot(x="species", y="sepal_length", data=iris)
plt.title("Boxplot with Custom Settings")
plt.show()

# Reset Matplotlib to its original configuration
sns.reset_orig()

# Plot with original Matplotlib settings
sns.boxplot(x="species", y="sepal_length", data=iris)
plt.title("Boxplot with Original Matplotlib Settings")
plt.show()

# %% [markdown]
# #(37)sns.plotting_context() =>
# - Retrieves the current plotting context settings in Seaborn. The plotting context determines the overall size and style of the plot elements, such as font sizes and line widths.

# %%
# Get the current plotting context
current_context = sns.plotting_context()
print("Current Plotting Context:", current_context)

# Set a new plotting context
sns.set_context("talk")
sns.scatterplot(x="sepal_length", y="sepal_width", hue="species", data=iris)
plt.title("Scatterplot with Talk Context")
plt.show()
# Out:
# Current Plotting Context: {'font.size': 10.0, 'axes.labelsize': 'medium', 'axes.titlesize': 'large', 'xtick.labelsize': 'medium', 'ytick.labelsize': 'medium', 'legend.fontsize': 'medium', 'legend.title_fontsize': None, 'axes.linewidth': 0.8, 'grid.linewidth': 0.8, 'lines.linewidth': 1.5, 'lines.markersize': 6.0, 'patch.linewidth': 1.0, 'xtick.major.width': 0.8, 'ytick.major.width': 0.8, 'xtick.minor.width': 0.6, 'ytick.minor.width': 0.6, 'xtick.major.size': 3.5, 'ytick.major.size': 3.5, 'xtick.minor.size': 2.0, 'ytick.minor.size': 2.0}

# %% [markdown]
# #(38)sns.scatterplot() => with axis
# -Creates a scatter plot using Seaborn.

# %%
# Create a plot
ax = sns.scatterplot(x="total_bill", y="tip", data=tips)

# Set axis labels
sns.set_axis_labels("Total Bill", "Tip")
plt.title("Scatterplot with Custom Axis Labels")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-066cc3b58e10> in <cell line: 5>()
#       3
#       4 # Set axis labels
# ----> 5 sns.set_axis_labels("Total Bill", "Tip")
#       6 plt.title("Scatterplot with Custom Axis Labels")
#       7 plt.show()
#
# AttributeError: module 'seaborn' has no attribute 'set_axis_labels'

# %% [markdown]
# #(39) set_xlabel() =>
# - Set a x-axis label on a Seaborn Plot

# %%
ax = sns.scatterplot(x="total_bill", y="tip", data=tips)

# Set x-axis  using Matplotlib's Axes methods
ax.set_xlabel("Total Bill Amount")


# Set plot title
plt.title("Scatterplot with Custom Axis Labels")

# Show the plot
plt.show()

# %% [markdown]
# #(40)sns.set_ylabel() =>
#  - Set the y-Axis Label on a Seaborn Plot

# %%
ax = sns.scatterplot(x="total_bill", y="tip", data=tips)

# Set y-axis  using Matplotlib's Axes methods
ax.set_ylabel("Total Bill Amount")


# Set plot title
plt.title("Scatterplot with Custom Axis Labels")

# Show the plot
plt.show()

# %% [markdown]
# #(41)sns.set_xticks() =>
# - Set the x-Axis Ticks on a Seaborn Plot

# %%
# Create a plot
ax = sns.scatterplot(x="total_bill", y="tip", data=tips)

# Set x-axis ticks using Matplotlib's Axes object method
ax.set_xticks([10, 20, 30, 40, 50])

# Set plot title (optional)
plt.title("Scatterplot with Custom X-Axis Ticks")

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-c56476be5cd6> in <cell line: 2>()
#       1 # Create a plot
# ----> 2 ax = sns.scatterplot(x="total_bill", y="tip", data=tips)
#       3
#       4 # Set x-axis ticks using Matplotlib's Axes object method
#       5 ax.set_xticks([10, 20, 30, 40, 50])
#
# NameError: name 'sns' is not defined

# %% [markdown]
# #(42)sns.set_yticks() =>
# - Set the y-Axis Ticks on a Seaborn Plot

# %%
# Create a plot
ax = sns.scatterplot(x="total_bill", y="tip", data=tips)

# Set y-axis ticks using Matplotlib's Axes object method
ax.set_yticks([10, 20, 30, 40, 50])

# Set plot title (optional)
plt.title("Scatterplot with Custom y-Axis Ticks")

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-620ffae39b64> in <cell line: 2>()
#       1 # Create a plot
# ----> 2 ax = sns.scatterplot(x="total_bill", y="tip", data=tips)
#       3
#       4 # Set y-axis ticks using Matplotlib's Axes object method
#       5 ax.set_yticks([10, 20, 30, 40, 50])
#
# NameError: name 'sns' is not defined

# %% [markdown]
# #(43)set_xticks() =>
# -Define where the ticks should be placed on the x-axis.

# %%
# Create a plot
ax = sns.scatterplot(x="total_bill", y="tip", data=tips)

# Set x-axis tick labels
ax.set_xticklabels(['Low', 'Medium', 'High'], rotation=40)
plt.title("Scatterplot with Custom x-Axis Tick Labels")
plt.show()
# Out:
# <ipython-input-37-bcbb2291a86f>:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(['Low', 'Medium', 'High'], rotation=40)

# %% [markdown]
# #(44)set_yticklabels () =>
# -Define where the ticks should be placed on the y-axis.

# %%
# Create a plot
ax = sns.scatterplot(x="total_bill", y="tip", data=tips)

# Set y-axis tick labels
ax.set_yticklabels(['Very Low', 'Low', 'Medium', 'High', 'Very High'])
plt.title("Scatterplot with Custom y-Axis Tick Labels")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-f7d7f1411301> in <cell line: 2>()
#       1 # Create a plot
# ----> 2 ax = sns.scatterplot(x="total_bill", y="tip", data=tips)
#       3
#       4 # Set y-axis tick labels
#       5 ax.set_yticklabels(['Very Low', 'Low', 'Medium', 'High', 'Very High'])
#
# NameError: name 'sns' is not defined

# %% [markdown]
# #(45)sns.set_ticklabels() =>
# - Set Both x and y-Axis Tick Labels

# %%
# Create a plot
ax = sns.scatterplot(x="total_bill", y="tip", data=tips)

# Set both x and y-axis tick labels
ax.set_xticklabels(['Low', 'Medium', 'High'], rotation=45)
ax.set_yticklabels(['Very Low', 'Low', 'Medium', 'High', 'Very High'])
plt.title("Scatterplot with Custom Tick Labels")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-848fb02182f1> in <cell line: 2>()
#       1 # Create a plot
# ----> 2 ax = sns.scatterplot(x="total_bill", y="tip", data=tips)
#       3
#       4 # Set both x and y-axis tick labels
#       5 ax.set_xticklabels(['Low', 'Medium', 'High'], rotation=45)
#
# NameError: name 'sns' is not defined

# %% [markdown]
# #(46)sns.set_legend () =>
# - Add a Legend to a Seaborn Plot

# %%
# Create a plot
ax = sns.scatterplot(x="total_bill", y="tip", hue="day", data=tips)

# Customize the legend
plt.legend(title="Day of the Week")

# Set plot title
plt.title("Scatterplot with Legend")

# Show the plot
plt.show()

# %% [markdown]
# #(47)sns.move_legend ()
# - Adjust the Legend's Position in a Seaborn Plot
# pyt

# %%
# Create a plot
ax = sns.scatterplot(x="total_bill", y="tip", hue="day", data=tips)

# Move the legend
sns.move_legend(ax, loc='upper left')
plt.title("Scatterplot with Moved Legend")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-10fecb0bf905> in <cell line: 2>()
#       1 # Create a plot
# ----> 2 ax = sns.scatterplot(x="total_bill", y="tip", hue="day", data=tips)
#       3
#       4 # Move the legend
#       5 sns.move_legend(ax, loc='upper left')
#
# NameError: name 'sns' is not defined

# %% [markdown]
# #(48)customise legend() =>

# %%
# Create a plot
ax = sns.scatterplot(x="total_bill", y="tip", hue="day", data=tips)

# Customize the legend
plt.legend(title="Day of the Week")

# Set plot title
plt.title("Scatterplot with Customized Legend")

# Show the plot
plt.show()

# %% [markdown]
# #(49)sns.remove_legend () =>
# - Remove the Legend from a Seaborn Plot

# %%
# Create a plot
ax = sns.scatterplot(x="total_bill", y="tip", hue="day", data=tips)

# Remove the legend
ax.get_legend().remove()

# Set plot title
plt.title("Scatterplot with Removed Legend")

# Show the plot
plt.show()

# %% [markdown]
# #(50)sns.set_figure_size () =>
# - Set the Size of the Figure for Seaborn Plots

# %%
# Set figure size
sns.set(rc={'figure.figsize':(10, 6)})

# Create a plot
sns.scatterplot(x="total_bill", y="tip", data=tips)
plt.title("Scatterplot with Custom Figure Size")
plt.show()

# %% [markdown]
# #(51)sns.set_size_inches() =>
#  - Set the Size of the Figure in Inches

# %%
# Create a plot
fig = plt.figure(figsize=(12, 8))
sns.scatterplot(x="total_bill", y="tip", data=tips)
plt.title("Scatterplot with Set Size in Inches")
plt.show()

# %% [markdown]
# #(52)sns.set_aspect () =>
# - Set the Aspect Ratio of a Seaborn Plot

# %%
# Create a plot
ax = sns.scatterplot(x="total_bill", y="tip", data=tips)

# Set aspect ratio
#'equal': Ensures that the units are the same on both the x and y axes, making each unit length the same on both axes
#This means that one unit on the x-axis will have the same length as one unit on the y-axis, which is useful for maintaining the proportionality of the data points.
ax.set_aspect('equal')
plt.title("Scatterplot with Equal Aspect Ratio")
plt.show()

# %% [markdown]
# #(53) sns.set_xlim () =>
# - Set the limits of the x-axis.

# %%
ax = sns.scatterplot(data=tips, x='total_bill', y='tip')
ax.set_xlim(left=0, right=60) #set limits to x-axis
plt.show()

# %% [markdown]
# #(54)sns.set_ylim () =>
# - Set the limits of the y-axis.

# %%
ax = sns.scatterplot(data=tips, x='total_bill', y='tip')
ax.set_ylim(bottom=0, top=12) #Set the limits of the y-axis.
plt.show()

# %% [markdown]
# #(55)ax.get_xlim() =>
# -to get the current xlimits

# %%
xlim = ax.get_xlim()
print("X-Limits:", xlim)
plt.show()
# Out:
# X-Limits: (0.6829999999999998, 53.197)

# %% [markdown]
# #(56)sns.set_ylim () =>
# - Set the limits of the y-axis.

# %%
ylim = ax.get_ylim()
print("Y-Limits:", ylim)
plt.show()
# Out:
# Y-Limits: (0.0, 12.0)

# %% [markdown]
# #(57)sns.set_grid () =>
# - Set grid visibility on seaborn plots.

# %%
ax.grid(True)  # This is actually Matplotlib's function
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-368799caae8a> in <cell line: 1>()
# ----> 1 ax.grid(True)  # This is actually Matplotlib's function
#       2 plt.show()
#
# NameError: name 'ax' is not defined

# %% [markdown]
# #(58)sns.gridplot () =>
# - Create a grid plot layout.

# %%
#col="time" specifies that the grid should be split into columns based on the unique values in the "time" column of the dataset.
#row="sex" specifies that the grid should also be split into rows based on the unique values in the "sex" column of the dataset.
g = sns.FacetGrid(tips, col="time", row="sex")
g.map(sns.scatterplot, 'total_bill', 'tip')
plt.show()

# %% [markdown]
# #(59)sns.add_grid() =>
#  - Add a grid to a seaborn plot.

# %%
ax = sns.scatterplot(data=tips, x='total_bill', y='tip')
ax.grid(True)  # Add grid
plt.show()

# %% [markdown]
# #(60)sns.remove_grid () =>
#  - Remove the grid from a seaborn plot.

# %%
ax = sns.scatterplot(data=tips, x='total_bill', y='tip')
ax.grid(False)  # Remove grid
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-493b2d12eee7> in <cell line: 1>()
# ----> 1 ax = sns.scatterplot(data=tips, x='total_bill', y='tip')
#       2 ax.grid(False)  # Remove grid
#       3 plt.show()
#
# NameError: name 'sns' is not defined

# %% [markdown]
# #(61)sns.set_frame() =>
# - Set frame visibility on seaborn plots.

# %%
ax = sns.scatterplot(data=tips, x='total_bill', y='tip')
ax.spines['top'].set_visible(False)  # Remove top border
ax.spines['right'].set_visible(False)  # Remove right border
plt.show()

# %% [markdown]
# #(62)sns.add_frame() =>
#  - Add a frame around a seaborn plot.

# %%
## (This is done by setting the visibility of the spines, which act as the frame)

ax.spines['top'].set_visible(True)
ax.spines['right'].set_visible(True)
ax.spines['bottom'].set_visible(True)
ax.spines['left'].set_visible(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-f3d96a89af63> in <cell line: 3>()
#       1 ## (This is done by setting the visibility of the spines, which act as the frame)
#       2
# ----> 3 ax.spines['top'].set_visible(True)
#       4 ax.spines['right'].set_visible(True)
#       5 ax.spines['bottom'].set_visible(True)
#
# NameError: name 'ax' is not defined

# %% [markdown]
# #(63)sns.remove_frame() =>
#  - Remove the frame from a seaborn plot.

# %%
#fig, ax = plt.subplots():

#This creates a new figure and a single subplot (axis) for plotting.
#fig is the figure object, and ax is the axes object where the plot will be drawn.

fig, ax = plt.subplots()
sns.scatterplot(data=tips, x='total_bill', y='tip', ax=ax)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-e90a09c4b01c> in <cell line: 6>()
#       4 #fig is the figure object, and ax is the axes object where the plot will be drawn.
#       5
# ----> 6 fig, ax = plt.subplots()
#       7 sns.scatterplot(data=tips, x='total_bill', y='tip', ax=ax)
#       8 ax.spines['top'].set_visible(False)
#
# NameError: name 'plt' is not defined

# %% [markdown]
# #(64)sns.set_spine_position() =>
#  - Set position of plot spines

# %%
#fig, ax = plt.subplots():

#This creates a new figure and a single subplot (axis) for plotting.
#fig is the figure object, and ax is the axes object where the plot will be drawn.
fig, ax = plt.subplots()
sns.scatterplot(data=tips, x='total_bill', y='tip', ax=ax)
ax.spines['bottom'].set_position('zero')  # Move bottom spine to zero position
plt.show()

# %% [markdown]
# #(65)sns.set_spine_color() =>
#  - Set color for plot spines.

# %%
#fig, ax = plt.subplots():

#This creates a new figure and a single subplot (axis) for plotting.
#fig is the figure object, and ax is the axes object where the plot will be drawn.
fig, ax = plt.subplots()
sns.scatterplot(data=tips, x='total_bill', y='tip', ax=ax)
ax.spines['top'].set_color('red')  # Set color for the top spine
plt.show()

# %% [markdown]
# #(66)sns.set_spine_linewidth() =>
# - Set linewidth for plot spines.

# %%
#fig, ax = plt.subplots():

#This creates a new figure and a single subplot (axis) for plotting.
#fig is the figure object, and ax is the axes object where the plot will be drawn.
fig, ax = plt.subplots()
sns.scatterplot(data=tips, x='total_bill', y='tip', ax=ax)
ax.spines['top'].set_linewidth(2)  # Set linewidth for the top spine
plt.show()

# %% [markdown]
# #(67)sns.set_legend_title () =>
# - Set the title of the legend.

# %%
#fig, ax = plt.subplots():

#This creates a new figure and a single subplot (axis) for plotting.
#fig is the figure object, and ax is the axes object where the plot will be drawn.
fig, ax = plt.subplots()
sns.scatterplot(data=tips, x='total_bill', y='tip', ax=ax, hue='day')
legend = ax.legend(title='Day of the Week')
plt.show()

# %% [markdown]
# #(68)sns.set_facecolor () =>
# - Set the face color of the figure

# %%
# Create a plot
fig, ax = plt.subplots()
fig.patch.set_facecolor('lightgrey')  # Set face color for the figure background
plt.show()

# %% [markdown]
# #(69)sns.set_edgecolor() =>
#  - Set the edge color of the figure.

# %%
# Create a plot
fig, ax = plt.subplots()
fig.patch.set_edgecolor('black')  # Set edge color for the figure border
plt.show()

# %% [markdown]
# #(70)sns.set_alpha () =>
# - Set the transparency of plot elements.

# %%
#alpha=0.5: Sets the transparency level of the plot markers. The alpha parameter ranges from 0 to 1, where 0 is fully transparent and 1 is fully opaque. Here,
# alpha=0.5 makes the markers semi-transparent.
sns.scatterplot(data=tips, x='total_bill', y='tip', alpha=0.5)  # Set transparency
plt.show()

# %% [markdown]
# #(71)sns.scatterplot() => with custome arguments

# %%
#x: Data for x-axis.
#y: Data for y-axis.
#hue: Variable to color points by.
#size: Variable to scale point size.
#style: Variable to determine point style.
#palette: Color palette to use.
df = pd.DataFrame({
    'x_col': [1, 2, 3, 4, 5],
    'y_col': [5, 4, 3, 2, 1],
    'category': ['A', 'B', 'A', 'B', 'A'],
    'size_col': [10, 20, 15, 25, 30],
    'line_style': ['--', '-', '--', '-', '--']
})
sns.scatterplot(data=df, x='x_col', y='y_col', hue='category', size='size_col', palette='viridis')
plt.show()

# %% [markdown]
# #(72)sns.lineplot() => with custome arguments

# %%
#x: Data for x-axis.
#y: Data for y-axis.
#hue: Variable to color lines by.
#style: Variable to determine line style.
#ci: Confidence interval to display.
#palette: Color palette to use.
sns.lineplot(data=df, x='x_col', y='y_col', hue='category', style='line_style', errorbar='sd')
plt.show()
