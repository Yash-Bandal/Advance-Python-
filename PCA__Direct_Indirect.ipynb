# %% [markdown]
# <a href="https://colab.research.google.com/github/Yash-Bandal/Advance-Python-/blob/main/PCA__Direct_Indirect.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Indirect Method

# %%
#1 Get data
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#dummy dataset
print("Data :")
X=np.random.randint(10,50,100).reshape(20,5)
X
# Out:
# Data :
# array([[31, 23, 25, 16, 13],
#        [33, 40, 43, 43, 49],
#        [39, 39, 44, 14, 19],
#        [12, 11, 17, 22, 10],
#        [19, 46, 48, 39, 38],
#        [25, 35, 21, 41, 19],
#        [30, 49, 12, 38, 28],
#        [39, 27, 46, 27, 34],
#        [17, 10, 40, 20, 26],
#        [32, 45, 37, 23, 40],
#        [30, 20, 27, 16, 15],
#        [26, 29, 11, 25, 27],
#        [26, 18, 40, 16, 43],
#        [30, 49, 37, 38, 43],
#        [38, 47, 18, 31, 24],
#        [44, 16, 25, 15, 19],
#        [47, 15, 19, 27, 43],
#        [18, 40, 26, 10, 31],
#        [33, 20, 17, 43, 17],
#        [16, 38, 47, 45, 12]])

# %%
# 2 Find mean and subtracct from X..row wise mean
print("Mean :")
mean=np.mean(X,axis=0)  #0 rep row but calculate of cols axis 1------------->   axis0 ulta
mean
# Out:
# Mean :
# array([26.45, 27.9 , 27.15, 27.4 , 27.75])

# %%
X_meaned=X-mean
X_meaned
# Out:
# array([[-14.45,   9.1 ,  -7.15,  -0.4 ,  18.25],
#        [  5.55,  -7.9 , -15.15,  -9.4 ,  -8.75],
#        [  2.55,   6.1 ,  -8.15,   6.6 , -11.75],
#        [  2.55,  -0.9 ,  20.85,   6.6 , -11.75],
#        [ 13.55,   4.1 ,  -2.15,  -6.4 ,  -7.75],
#        [  0.55,   6.1 ,  15.85,  17.6 ,  14.25],
#        [ 12.55,  17.1 ,   7.85,   5.6 , -13.75],
#        [ 21.55, -17.9 ,  -8.15,  17.6 ,   3.25],
#        [-12.45,  -6.9 ,  -2.15,  -8.4 ,  16.25],
#        [ 11.55,  -7.9 , -16.15, -14.4 ,  12.25],
#        [  8.55,  -5.9 ,   1.85,   4.6 ,  -3.75],
#        [ -1.45,  -3.9 ,  20.85,   1.6 , -11.75],
#        [ -3.45, -12.9 ,  16.85,  19.6 , -12.75],
#        [ -5.45,  11.1 ,   2.85, -15.4 ,  19.25],
#        [-11.45,  -1.9 ,  12.85,  -7.4 ,  10.25],
#        [-14.45,   1.1 , -11.15, -14.4 , -16.75],
#        [ -8.45,   8.1 ,  -4.15,  -8.4 ,  -7.75],
#        [  7.55,   6.1 , -15.15,  -4.4 ,  19.25],
#        [ -3.45,  -0.9 , -16.15,  -8.4 ,   1.25],
#        [-11.45,  -1.9 ,   5.85,  17.6 ,  -7.75]])

# %%
#3 Covariance Matrix

#observations (rows) and  variables (columns)..here rowvar=false means variables is in col..if true variable in row
print("Covariance Matrix :")
cov_mat=np.cov(X_meaned,rowvar=False)
cov_mat
# Out:
# Covariance Matrix :
# array([[109.20789474, -17.47894737, -19.49210526,  26.81052632,
#         -15.19736842],
#        [-17.47894737,  74.30526316,   3.12105263, -23.22105263,
#          10.71052632],
#        [-19.49210526,   3.12105263, 157.50263158,  74.04210526,
#         -36.32894737],
#        [ 26.81052632, -23.22105263,  74.04210526, 132.77894737,
#         -36.63157895],
#        [-15.19736842,  10.71052632, -36.32894737, -36.63157895,
#         164.51315789]])

# %%
# 4 Compute Eigen Vectors and Eigen values
print("Eigen Vectors and Eigen values :")
eigen_values,eigen_vectors=np.linalg.eigh(cov_mat)


print("Eigen Vectors :")
eigen_vectors
# Out:
# Eigen Vectors and Eigen values :
# Eigen Values :
# Eigen Vectors :
# array([[ 0.34070655, -0.51327439, -0.50806808,  0.59509687, -0.09052623],
#        [-0.41770327, -0.83054281,  0.26041339, -0.2391148 ,  0.1035934 ],
#        [ 0.52562402, -0.18261475, -0.00340206, -0.55535485, -0.61801348],
#        [-0.65694169,  0.11494369, -0.47254867, -0.01579441, -0.57590265],
#        [ 0.03987528, -0.01370534, -0.67137015, -0.52916478,  0.51717394]])

# %%
#5 Sort Eig values in Descending Order to get highest element first
# 0  1  2        1  2  0
#[30 10 20]  -->[10 20 30]  sorted ascending
#Thus, np.argsort(arr) returns [1, 2, 0] because:

sorted_indices=np.argsort(eigen_values)[::-1]
sorted_indices
# Out:
# array([4, 3, 2, 1, 0])

# %%
# we cant directly print sorted eigenvalues so we first sort them internally and get their order of sorting with argsort
sorted_eigenValues=eigen_values[sorted_indices]
sorted_eigenValues
# Out:
# array([253.52248186, 147.22349697, 122.89042654,  67.57997349,
#         47.09151589])

# %%
sorted_vectors=eigen_vectors[:,sorted_indices]
sorted_vectors
# Out:
# array([[-0.09052623,  0.59509687, -0.50806808, -0.51327439,  0.34070655],
#        [ 0.1035934 , -0.2391148 ,  0.26041339, -0.83054281, -0.41770327],
#        [-0.61801348, -0.55535485, -0.00340206, -0.18261475,  0.52562402],
#        [-0.57590265, -0.01579441, -0.47254867,  0.11494369, -0.65694169],
#        [ 0.51717394, -0.52916478, -0.67137015, -0.01370534,  0.03987528]])

# %%
#6 Select subsets from each sorted

# select the first n eigenvectors, n is desired dimension
# of our final reduced data.
##7.22,5.66,4.4,

n_componants=2
eigenvector_subset=sorted_vectors[:,0:n_componants]
eigenvector_subset
# Out:
# array([[-0.09052623,  0.59509687],
#        [ 0.1035934 , -0.2391148 ],
#        [-0.61801348, -0.55535485],
#        [-0.57590265, -0.01579441],
#        [ 0.51717394, -0.52916478]])

# %%
#7 Transform the data
X_reduced_pretranspose=np.dot(eigenvector_subset.transpose(),X_meaned.transpose())
X_reduced=X_reduced_pretranspose.transpose()
X_reduced
# Out:
# array([[ 16.3383859 , -16.45524668],
#        [  8.93030868,  18.38407975],
#        [ -4.43986354,  10.69848176],
#        [-23.08740833,  -3.73300521],
#        [  0.20451039,  12.47931604],
#        [-11.97954128, -17.75225108],
#        [-14.55225938,   6.20763402],
#        [ -7.2234236 ,  19.63286721],
#        [ 14.98264488, -13.03130552],
#        [ 22.74533078,  11.47652751],
#        [ -7.11707975,   7.38316268],
#        [-20.15657038,  -5.31707622],
#        [-29.31922619,  -1.88895199],
#        [ 18.70641544, -17.42340155],
#        [  2.46093714, -18.80291111],
#        [  7.94324171,   6.42098012],
#        [  4.99829336,  -0.42697569],
#        [ 21.80092097,   1.33108043],
#        [ 15.68404883,   6.60231701],
#        [-16.91966561,  -5.78532147]])

# %% [markdown]
# The final dimensions of X_reduced will be ( 20, 2 ) and originally the data was of higher dimensions ( 20, 5 ).
#
# Now we can visualize our data with the available tools we have

# %%
X_reduceFinal=pd.DataFrame(X_reduced,columns=["Dim 1", "Dim 2"])
X_reduceFinal
# Out:
#         Dim 1      Dim 2
# 0   16.338386 -16.455247
# 1    8.930309  18.384080
# 2   -4.439864  10.698482
# 3  -23.087408  -3.733005
# 4    0.204510  12.479316
# 5  -11.979541 -17.752251
# 6  -14.552259   6.207634
# 7   -7.223424  19.632867
# 8   14.982645 -13.031306
# 9   22.745331  11.476528
# 10  -7.117080   7.383163
# 11 -20.156570  -5.317076
# 12 -29.319226  -1.888952
# 13  18.706415 -17.423402
# 14   2.460937 -18.802911
# 15   7.943242   6.420980
# 16   4.998293  -0.426976
# 17  21.800921   1.331080
# 18  15.684049   6.602317
# 19 -16.919666  -5.785321

# %%
# prompt: perform pca on above data  X using internal pca function

import numpy as np
import pandas as pd

# Assuming X is already defined as in the provided code
X = np.array(
      [[31, 23, 25, 16, 13],
       [33, 40, 43, 43, 49],
       [39, 39, 44, 14, 19],
       [12, 11, 17, 22, 10],
       [19, 46, 48, 39, 38],
       [25, 35, 21, 41, 19],
       [30, 49, 12, 38, 28],
       [39, 27, 46, 27, 34],
       [17, 10, 40, 20, 26],
       [32, 45, 37, 23, 40],
       [30, 20, 27, 16, 15],
       [26, 29, 11, 25, 27],
       [26, 18, 40, 16, 43],
       [30, 49, 37, 38, 43],
       [38, 47, 18, 31, 24],
       [44, 16, 25, 15, 19],
       [47, 15, 19, 27, 43],
       [18, 40, 26, 10, 31],
       [33, 20, 17, 43, 17],
       [16, 38, 47, 45, 12]])

X

# Using sklearn's PCA
from sklearn.decomposition import PCA

# Create a PCA object with the desired number of components
pca = PCA(n_components=2)

# Fit the PCA model to your data
pca.fit(X)

# Transform the data using the fitted model
X_reduced = pca.transform(X)

# Convert the transformed data into a DataFrame for better visualization
X_reduceFinal = pd.DataFrame(X_reduced, columns=["Dim 1", "Dim 2"])

X_reduceFinal
# Out:
#         Dim 1      Dim 2
# 0  -18.765087   0.025672
# 1   28.005688   5.907900
# 2    1.928167  10.198000
# 3  -29.461159  -6.240504
# 4   26.896553   3.313409
# 5    0.197185 -17.979335
# 6    9.104517 -24.124867
# 7    7.135558  15.709300
# 8  -13.647528  16.997469
# 9   16.647115   6.255092
# 10 -18.990486   3.237675
# 11 -10.271631 -11.088072
# 12  -1.491067  23.148162
# 13  26.614609  -1.774587
# 14   5.684272 -16.752883
# 15 -20.678327   6.774103
# 16  -7.401098   6.838981
# 17  -0.895605   2.708389
# 18 -11.468131 -15.695057
# 19  10.856453  -7.458847

# %% [markdown]
# --------------------------------------------------------------------------------

# %% [markdown]
# ## Direct Method

# %%
###PCA on IRIS dataset

import pandas as pd
from sklearn.decomposition import PCA

#Get the IRIS dataset
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
data = pd.read_csv(url, names=['sepal length','sepal width','petal length','petal width','target'])
data
# Out:
#      sepal length  sepal width  petal length  petal width          target
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# get first 4 features except target..as we perform PCA on first 4
#prepare the data
x = data.iloc[:,0:4]
x
# Out:
#      sepal length  sepal width  petal length  petal width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
#prepare the target
target = data.iloc[:,4]
target
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: target, Length: 150, dtype: object

# %%
#Applying it to PCA function
#mat_reduced = PCA(n_components=2)

pca=PCA(n_components=3)
principalComponents = pca.fit_transform(x)

#Creating a Pandas DataFrame of reduced Dataset
principal_df = pd.DataFrame(principalComponents , columns = ['PC1', 'PC2','PC3'])

#Concat it with target variable to create a complete Dataset
#final concatenated
principal_df = pd.concat([principal_df , pd.DataFrame(target)] , axis = 1)
principal_df
# Out:
#           PC1       PC2       PC3          target
# 0   -2.684207  0.326607 -0.021512     Iris-setosa
# 1   -2.715391 -0.169557 -0.203521     Iris-setosa
# 2   -2.889820 -0.137346  0.024709     Iris-setosa
# 3   -2.746437 -0.311124  0.037672     Iris-setosa
# 4   -2.728593  0.333925  0.096230     Iris-setosa
# ..        ...       ...       ...             ...
# 145  1.944017  0.187415  0.179303  Iris-virginica
# 146  1.525664 -0.375021 -0.120636  Iris-virginica
# 147  1.764046  0.078519  0.130784  Iris-virginica
# 148  1.901629  0.115877  0.722874  Iris-virginica
# 149  1.389666 -0.282887  0.362318  Iris-virginica
#
# [150 rows x 4 columns]

# %%
import seaborn as sb
import matplotlib.pyplot as plt

plt.figure(figsize = (6,6))
sb.scatterplot(data = principal_df , x = 'PC1',y = 'PC2' , hue = 'target' , s = 60 , palette= 'icefire')
# Out:
# <Axes: xlabel='PC1', ylabel='PC2'>
