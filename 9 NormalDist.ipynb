# %% [markdown]
# #Importing the required Packages

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
from scipy.stats import skew,kurtosis
import seaborn as sns

# %% [markdown]
# #Normal Distribution , skewness , kurtosis

# %%
# for standard normal distribution mean=0 and S.D=1
mu=0
std=1
sns=stats.norm(mu,std)

# generate 100 random values
x=np.linspace(-5,5,100)

plt.plot(x, norm.pdf(x, mu, std))
plt.show()

#generate random test scores following a normal distrbution
test_scores=np.random.normal(loc=75,scale=10,size=100)

print(skew(test_scores))
print(kurtosis(test_scores))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-ce045f96b811> in <cell line: 4>()
#       2 mu=0
#       3 std=1
# ----> 4 sns=stats.norm(mu,std)
#       5
#       6 # generate 100 random values
#
# NameError: name 'stats' is not defined

# %%
plt.hist(test_scores)
plt.title('Test Scores Distribution')
plt.legend()  # Add this line to display the legend
plt.show()  # Add this line to display the plot
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-424fce7de240> in <cell line: 1>()
# ----> 1 plt.hist(test_scores)
#       2 plt.title('Test Scores Distribution')
#       3 plt.legend()  # Add this line to display the legend
#       4 plt.show()  # Add this line to display the plot
#
# NameError: name 'test_scores' is not defined

# %%
#normal distribution for test scores
mean1=75
std1=10
x = np.linspace(mean1 - 4*std1, mean1 + 4*std1, 1000)
plt.plot(x, norm.pdf(x, mean1, std1))
plt.show()
